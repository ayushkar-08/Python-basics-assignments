# %% [markdown]
# #  Python Sets – Practice Questions

# %% [markdown]
# ### Q1
# Create a set from the list below and print only the unique values.
#
# ```python
# data = [10, 20, 20, 30, 40, 40]
# ```

# %%
# write your code here
data=[10,20,20,30,40,50]
d=set(data)
print(d)
# Out:
# {40, 10, 50, 20, 30}

# %% [markdown]
# ### Q2
# What will be the output? Explain why.
#
# ```python
# s = {1, 2, 3, 3, 2}
# print(s)
# ```

# %%
# write your code here
s={1,2,3,3,2}
print(s) # set gives us unique elements of the set
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Q3
# Create an empty set and add numbers from 1 to 5 using a loop.

# %%
# write your code here
s=set()
for i in range(1,6):
    s.add(i)
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ### Q4
# Why does this code give an error? Fix it.
#
# ```python
# s = {}
# s.add(10)
# ```

# %%
# write your code here
# empty curly brackets gives us type dictionary thats why it's not addable
s=set()
s.add(10)
print(s)
# Out:
# {10}

# %% [markdown]
# ### Q5
# Given:
# ```python
# A = {2, 4, 6, 8}
# B = {4, 8, 12}
# ```
# Find Union, Intersection, A-B

# %%
# write your code here
A={2,4,6,8}
B={4,8,12}
print(A.union(B))
print(A.intersection(B))
print(A.difference(B))
# Out:
# {2, 4, 6, 8, 12}
# {8, 4}
# {2, 6}

# %% [markdown]
# ### Q6
# Check whether 15 exists in the set {5, 10, 15, 20}.

# %%
# write your code here
s={5,10,15,20}
for i in s:
    if i==15:
       print("yes")
       break
else:
       print("no")
# Out:
# yes

# %% [markdown]
# ### Q7
# Remove element 30 safely from {10, 20, 30, 40}.

# %%
# write your code here
s={10,20,30,40}
s.discard(30)
print(s)
# Out:
# {40, 10, 20}

# %% [markdown]
# ### Q8
# Count unique elements in:
# ```python
# nums = [1, 2, 2, 3, 4, 4, 5]
# ```

# %%
# write your code here
nums=[1,2,2,3,4,4,5]
print(len(set(nums)))
# Out:
# 5

# %% [markdown]
# ### Q9
# What will be the output?
# ```python
# s = {10, 20, 30}
# s.add(20)
# print(len(s))
# ```

# %%
# write your code here
s = {10, 20, 30}
s.add(20)
print(len(s))
# Out:
# 3

# %% [markdown]
# ### Q10
# Can a set contain a list? Why?
# ```python
# s = {1, 2, [3, 4]}
# ```

# %%
# write your code here
s = {1, 2, [3, 4]}
print(s) # ist is mmutable thats why it can't be stored in set and whereas tuple can be stored as it is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4137712875.py in <cell line: 0>()
#       1 # write your code here
# ----> 2 s = {1, 2, [3, 4]}
#       3 print(s)
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ### Q11
# Convert {100, 200, 300} into list and print first element.

# %%
# write your code here
s={100,200,300}
l=list(s)
print(l)
# Out:
# [200, 100, 300]

# %% [markdown]
# ### Q12
# Students in two classes:
# ```python
# class_A = {'Aman','Riya','Karan','Neha'}
# class_B = {'Neha','Simran','Aman'}
# ```

# %%
# write your code here
class_A = {'Aman','Riya','Karan','Neha'}
class_B = {'Neha','Simran','Aman'}
print(class_A.union(class_B))
# Out:
# {'Simran', 'Karan', 'Riya', 'Neha', 'Aman'}

# %% [markdown]
# ### Q13
# Find unique characters in:
# ```python
# text = 'programming'
# ```

# %%
# write your code here
text='programming'
print(set(text))
# Out:
# {'m', 'i', 'r', 'g', 'o', 'a', 'n', 'p'}

# %% [markdown]
# ### Q14
# Remove duplicate words from:
# ```python
# sentence = 'python is easy and python is powerful'
# ```

# %%
# write your code here
sentence = 'python is easy and python is powerful'
s=set(sentence.split()) # split sepreate the words
print(s)
# Out:
# {'easy', 'powerful', 'is', 'python', 'and'}

# %% [markdown]
# ### Q15
# What is the output?
# ```python
# s = set('hello')
# print(s)
# ```

# %%
# write your code here
s = set('hello')
print(s)
# Out:
# {'h', 'l', 'o', 'e'}
